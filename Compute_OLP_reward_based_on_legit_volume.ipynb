# %%
import requests
import pandas as pd 
import json

legit_volume = 59221.161000001244

market = [
                {
                    "marketId": "0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70",
                    "ticker": "ZRO/USDT PERP",
                    "preAllocatedReward":"null"
                }
            ]

df = pd.DataFrame(market)

df.drop("preAllocatedReward", axis=1, inplace=True)

# %%
def inj_sim(volume):
 
    response = {'next': {'height': 66320416, 'perPage': 100, 'total': 15}, 'scores': [{'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj168rzv04sfrglf868evsecjdzs48wt2pruycrwq', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 6251379104118.6045, 'ask': 5926704617617.135, 'depth': 2141254597.8072, 'snapshotCount': 50025, 'liquidityScore': 5723565781826.869, 'liquidityScorePonderated': 126784.64864788039, 'uptimeScore': 49431, 'uptimeScorePonderated': 120780879929991, 'uptimePercentage': 98.81259370314844, 'startVolume': 11628037.6349, 'currentVolume': 17404193.7718, 'volume': 5776156.1369, 'volumeScore': 5776156.1369, 'volumeScorePonderated': 256632.19551679833, 'takerStartVolume': 215145.9667, 'takerCurrentVolume': 228146.2316, 'takerVolume': 13000.2649, 'makerStartVolume': 11412891.6682, 'makerCurrentVolume': 17176047.5402, 'makerVolume': 5763155.872, 'totalScore': 3.929850236879356e+24, 'reward': 606.3959040750723, 'rewardPercentage': 97.11973752212054, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj14k7wgey85pt226ugr9sq4h2ya774n82hzy26nf', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 1204229846639.9832, 'ask': 1188525997042.6497, 'depth': 140409409.0173, 'snapshotCount': 50025, 'liquidityScore': 1176340604787.8447, 'liquidityScorePonderated': 67330.71638272084, 'uptimeScore': 46930, 'uptimeScorePonderated': 103359800557000, 'uptimePercentage': 93.81309345327335, 'startVolume': 2399091.3678, 'currentVolume': 2548471.9483, 'volume': 149380.5805, 'volumeScore': 149380.5805, 'volumeScorePonderated': 13785.906042211085, 'takerStartVolume': 238280.2914, 'takerCurrentVolume': 253956.8906, 'takerVolume': 15676.5992, 'makerStartVolume': 2160811.0764, 'makerCurrentVolume': 2294515.0577, 'makerVolume': 133703.9813, 'totalScore': 9.594011001887633e+22, 'reward': 14.804047545118827, 'rewardPercentage': 2.37100086294273, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1xyc8au3vwlxgnnt7vyjxvz83twpdp8lde3qmkg', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 4299008896265.927, 'ask': 4624120231187.862, 'depth': 537217677.4486, 'snapshotCount': 50025, 'liquidityScore': 4175872688999.164, 'liquidityScorePonderated': 111763.21850484537, 'uptimeScore': 28473, 'uptimeScorePonderated': 23083395059817, 'uptimePercentage': 56.91754122938531, 'startVolume': 3555834.0664, 'currentVolume': 3617562.8237, 'volume': 61728.7573, 'volumeScore': 61728.7573, 'volumeScorePonderated': 6798.138795631657, 'takerStartVolume': 1102474.1889, 'takerCurrentVolume': 1143329.8625, 'takerVolume': 40855.6736, 'makerStartVolume': 2453359.8775, 'makerCurrentVolume': 2474232.9612, 'makerVolume': 20873.0837, 'totalScore': 1.753834510240978e+22, 'reward': 2.7062559622632723, 'rewardPercentage': 0.43343114120069, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1xnf7ndf362aa63vnwa7jkm7ua29xhqslnnxnn4', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 21399330357.742756, 'ask': 21555775886.486286, 'depth': 360365394.6242, 'snapshotCount': 50025, 'liquidityScore': 20780474844.621433, 'liquidityScorePonderated': 13398.685302322649, 'uptimeScore': 40651, 'uptimeScorePonderated': 67175932014451, 'uptimePercentage': 81.26136931534234, 'startVolume': 0, 'currentVolume': 26049.2652, 'volume': 26049.2652, 'volumeScore': 26049.2652, 'volumeScorePonderated': 3409.073633334272, 'takerStartVolume': 0, 'takerCurrentVolume': 15173.157, 'takerVolume': 15173.157, 'makerStartVolume': 0, 'makerCurrentVolume': 10876.1082, 'makerVolume': 10876.1082, 'totalScore': 3.068402085687137e+21, 'reward': 0.4734700674734998, 'rewardPercentage': 0.07583047373604, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1q8k2udwffmsjyxfm6tgmc2uj7zeyn6hvj5p7tq', 'height': 66320416, 'startHeight': 63802088, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 45911, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1cz9d7yhz8m4xl0zwx960qs3u5n8f493tq4407z', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj12vpajtjf5cvmk2w737m0t8qwwkyjz0xgvxwyus', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1utp6ktuhe96jjghdwhuz44wpxfgma6nkj8cjf5', 'height': 66320416, 'startHeight': 66110079, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 3845, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1rwv4zn3jptsqs7l8lpa3uvzhs57y8duemete9e', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1akxycslq8cjt0uffw4rjmfm3echchptu52a2dq', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1y9vkk3ga59gq96amj9np7l67nuhnwg6rv4a06j', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1pewdlzdte5dxmtphkgpy7pk774k7zzr4ljfqzd', 'height': 66320416, 'startHeight': 63986180, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 42600, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1frzh537rcnyluhus5g6tnam75w7epz77l0fg56', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1ttlsrcagq7gvwhc4l34wh4s4eq6r6sfx8ffd9f', 'height': 66320416, 'startHeight': 63573664, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 50025, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}, {'epochId': 'epoch_240319_240415', 'marketId': '0x7a70d95e24ba42b99a30121e6a4ff0d6161847d5b86cbfc3d4b3a81d8e190a70', 'accountAddress': 'inj1d07m5lngl5hs2wv0k52sqjp7qah8030gr2awf7', 'height': 66320416, 'startHeight': 64457748, 'blockTime': 1713225599657, 'bid': 0, 'ask': 0, 'depth': 0, 'snapshotCount': 33975, 'liquidityScore': 0, 'liquidityScorePonderated': 0, 'uptimeScore': 0, 'uptimeScorePonderated': 0, 'uptimePercentage': 0, 'startVolume': 0, 'currentVolume': 0, 'volume': 0, 'volumeScore': 0, 'volumeScorePonderated': 0, 'takerStartVolume': 0, 'takerCurrentVolume': 0, 'takerVolume': 0, 'makerStartVolume': 0, 'makerCurrentVolume': 0, 'makerVolume': 0, 'totalScore': 0, 'reward': 0, 'rewardPercentage': 0, 'createdAt': 1713226094037, 'updatedAt': 1713226094037}]}


    df = pd.DataFrame(response["scores"])

    filtered_df = df
    # Calculate the total volume of the filtered DataFrame

    total_reward =  df["reward"].sum()

    base_reward =  df.loc[df['accountAddress'].str.endswith('wq'), 'reward'].values[0]

    # Increase the volume for addresses ending with '26nf'
    df.loc[df['accountAddress'].str.endswith('wq'), 'volume'] = volume

    df["score"] = (df["liquidityScorePonderated"])*(df["uptimeScore"]**3)*(df["volume"]**0.8)

    total_score = df['score'].sum()

    # Calculate the percentage of each score relative to the total sum
    df['score_percentage'] = (df['score'] / total_score)

    df['reward_updated'] = df['score_percentage'] * total_reward
    
    
    return df

# %%
legit_volume = 59221.161000001244

for index, row in df.iterrows():
    market_id = row['marketId']
    df = inj_sim(volume=legit_volume)
    
selected_columns = ['accountAddress', 'reward','volume','reward_updated']
#df = df[df['reward_updated'] >= 1]
selected_df = df[selected_columns]

selected_df = selected_df.rename(columns={'reward': 'inj_reward_with_washtrading', 'reward_updated': 'inj_reward_without_washtrading'})

selected_df
# Out:
#                                 accountAddress  inj_reward_with_washtrading  \
# 0   inj168rzv04sfrglf868evsecjdzs48wt2pruycrwq                   606.395904
# 1   inj14k7wgey85pt226ugr9sq4h2ya774n82hzy26nf                    14.804048
# 2   inj1xyc8au3vwlxgnnt7vyjxvz83twpdp8lde3qmkg                     2.706256
# 3   inj1xnf7ndf362aa63vnwa7jkm7ua29xhqslnnxnn4                     0.473470
# 4   inj1q8k2udwffmsjyxfm6tgmc2uj7zeyn6hvj5p7tq                     0.000000
# 5   inj1cz9d7yhz8m4xl0zwx960qs3u5n8f493tq4407z                     0.000000
# 6   inj12vpajtjf5cvmk2w737m0t8qwwkyjz0xgvxwyus                     0.000000
# 7   inj1utp6ktuhe96jjghdwhuz44wpxfgma6nkj8cjf5                     0.000000
# 8   inj1rwv4zn3jptsqs7l8lpa3uvzhs57y8duemete9e                     0.000000
# 9   inj1akxycslq8cjt0uffw4rjmfm3echchptu52a2dq                     0.000000
# 10  inj1y9vkk3ga59gq96amj9np7l67nuhnwg6rv4a06j                     0.000000
# ...

# %%
selected_columns = ['accountAddress', 'reward','volume','reward_updated']
#df = df[df['reward_updated'] >= 1]
selected_df = df[selected_columns]

selected_df = selected_df.rename(columns={'reward': 'inj_reward_with_washtrading', 'reward_updated': 'inj_reward_without_washtrading'})

selected_df
# Out:
#                                 accountAddress  inj_reward_with_washtrading  \
# 0   inj168rzv04sfrglf868evsecjdzs48wt2pruycrwq                   606.395904
# 1   inj14k7wgey85pt226ugr9sq4h2ya774n82hzy26nf                    14.804048
# 2   inj1xyc8au3vwlxgnnt7vyjxvz83twpdp8lde3qmkg                     2.706256
# 3   inj1xnf7ndf362aa63vnwa7jkm7ua29xhqslnnxnn4                     0.473470
# 4   inj1q8k2udwffmsjyxfm6tgmc2uj7zeyn6hvj5p7tq                     0.000000
# 5   inj1cz9d7yhz8m4xl0zwx960qs3u5n8f493tq4407z                     0.000000
# 6   inj12vpajtjf5cvmk2w737m0t8qwwkyjz0xgvxwyus                     0.000000
# 7   inj1utp6ktuhe96jjghdwhuz44wpxfgma6nkj8cjf5                     0.000000
# 8   inj1rwv4zn3jptsqs7l8lpa3uvzhs57y8duemete9e                     0.000000
# 9   inj1akxycslq8cjt0uffw4rjmfm3echchptu52a2dq                     0.000000
# 10  inj1y9vkk3ga59gq96amj9np7l67nuhnwg6rv4a06j                     0.000000
# ...
